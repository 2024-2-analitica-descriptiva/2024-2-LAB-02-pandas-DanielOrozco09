# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')
df
# Out:
#     c0 c1  c2          c3
# 0    0  E   1  1999-02-28
# 1    1  A   2  1999-10-28
# 2    2  B   5  1998-05-02
# 3    3  A   3  1999-08-28
# 4    4  C   6  1999-12-01
# 5    5  A   7  1998-07-28
# 6    6  A   9  1997-02-28
# 7    7  B   1  1999-05-10
# 8    8  E   2  1997-04-12
# 9    9  B   3  1999-11-23
# 10  10  C   7  1998-01-17
# 11  11  C   5  1998-12-28
# 12  12  D   3  1999-10-15
# 13  13  E   8  1998-11-01
# 14  14  B   9  1999-08-12
# 15  15  D   1  1997-12-01
# 16  16  E   3  1997-07-28
# 17  17  D   5  1998-08-12
# 18  18  E   8  1999-08-24
# 19  19  E   9  1998-01-23
# 20  20  E   7  1999-06-22
# 21  21  E   3  1999-04-24
# 22  22  D   5  1999-06-25
# 23  23  A   1  1999-08-25
# 24  24  E   4  1997-07-26
# 25  25  E   6  1997-09-24
# 26  26  A   8  1997-09-28
# 27  27  E   5  1999-06-22
# 28  28  A   6  1999-07-29
# 29  29  C   0  1999-08-22
# 30  30  A   1  1998-04-26
# 31  31  D   2  1998-02-24
# 32  32  E   5  1999-03-24
# 33  33  B   4  1998-03-23
# ...

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')
df.shape[0]
# Out:
# 40

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')
grup = df.groupby('c1').size()
grup
# Out:
# c1
# A     8
# B     7
# C     5
# D     6
# E    14
# dtype: int64

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')
grup = df.groupby('c1')['c2'].mean()
grup
# Out:
# c1
# A    4.625000
# B    5.142857
# C    5.400000
# D    3.833333
# E    4.785714
# Name: c2, dtype: float64

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')
grup = df.groupby('c1')['c2'].max()
grup
# Out:
# c1
# A    9
# B    9
# C    9
# D    7
# E    9
# Name: c2, dtype: int64

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl1.tsv')

unicos = df['c4'].unique().tolist()
unicos.sort()
unicos = [elemento.upper() for elemento in unicos]
unicos
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')

grup = df.groupby('c1')['c2'].sum()

grup
# Out:
# c1
# A    37
# B    36
# C    27
# D    23
# E    67
# Name: c2, dtype: int64

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')

df['suma'] = df['c0'] + df['c2']

df
# Out:
#     c0 c1  c2          c3  suma
# 0    0  E   1  1999-02-28     1
# 1    1  A   2  1999-10-28     3
# 2    2  B   5  1998-05-02     7
# 3    3  A   3  1999-08-28     6
# 4    4  C   6  1999-12-01    10
# 5    5  A   7  1998-07-28    12
# 6    6  A   9  1997-02-28    15
# 7    7  B   1  1999-05-10     8
# 8    8  E   2  1997-04-12    10
# 9    9  B   3  1999-11-23    12
# 10  10  C   7  1998-01-17    17
# 11  11  C   5  1998-12-28    16
# 12  12  D   3  1999-10-15    15
# 13  13  E   8  1998-11-01    21
# 14  14  B   9  1999-08-12    23
# 15  15  D   1  1997-12-01    16
# 16  16  E   3  1997-07-28    19
# 17  17  D   5  1998-08-12    22
# 18  18  E   8  1999-08-24    26
# 19  19  E   9  1998-01-23    28
# 20  20  E   7  1999-06-22    27
# 21  21  E   3  1999-04-24    24
# 22  22  D   5  1999-06-25    27
# 23  23  A   1  1999-08-25    24
# 24  24  E   4  1997-07-26    28
# 25  25  E   6  1997-09-24    31
# 26  26  A   8  1997-09-28    34
# 27  27  E   5  1999-06-22    32
# ...

# %%
import pandas as pd
import datetime as datetime

df = pd.read_table('../files/input/tbl0.tsv')

df.at[35, 'c3'] = '1999-01-29'

df['c3'] = pd.to_datetime(df['c3'], format = '%Y-%m-%d')
df['year'] = df['c3'].dt.year.astype(str)
df
# Out:
#     c0 c1  c2         c3  year
# 0    0  E   1 1999-02-28  1999
# 1    1  A   2 1999-10-28  1999
# 2    2  B   5 1998-05-02  1998
# 3    3  A   3 1999-08-28  1999
# 4    4  C   6 1999-12-01  1999
# 5    5  A   7 1998-07-28  1998
# 6    6  A   9 1997-02-28  1997
# 7    7  B   1 1999-05-10  1999
# 8    8  E   2 1997-04-12  1997
# 9    9  B   3 1999-11-23  1999
# 10  10  C   7 1998-01-17  1998
# 11  11  C   5 1998-12-28  1998
# 12  12  D   3 1999-10-15  1999
# 13  13  E   8 1998-11-01  1998
# 14  14  B   9 1999-08-12  1999
# 15  15  D   1 1997-12-01  1997
# 16  16  E   3 1997-07-28  1997
# 17  17  D   5 1998-08-12  1998
# 18  18  E   8 1999-08-24  1999
# 19  19  E   9 1998-01-23  1998
# 20  20  E   7 1999-06-22  1999
# 21  21  E   3 1999-04-24  1999
# 22  22  D   5 1999-06-25  1999
# 23  23  A   1 1999-08-25  1999
# 24  24  E   4 1997-07-26  1997
# 25  25  E   6 1997-09-24  1997
# 26  26  A   8 1997-09-28  1997
# 27  27  E   5 1999-06-22  1999
# 28  28  A   6 1999-07-29  1999
# ...

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl0.tsv')

result = df.groupby('c1')['c2'].apply(lambda x: ':'.join(map(str, sorted(x)))).reset_index()
result = result.rename(columns = {'c1': '_c1'})
result.set_index('_c1', inplace = True)

result
# Out:
#                               c2
# _c1
# A                1:1:2:3:6:7:8:9
# B                  1:3:4:5:6:8:9
# C                      0:5:6:7:9
# D                    1:2:3:5:5:7
# E    1:1:2:3:3:4:5:5:5:6:7:8:8:9

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl1.tsv')

result = df.groupby('c0')['c4'].apply(lambda x: ','.join(map(str, sorted(x)))).reset_index()

result
# Out:
#     c0       c4
# 0    0    b,f,g
# 1    1    a,c,f
# 2    2  a,c,e,f
# 3    3      a,b
# 4    4  a,d,f,g
# 5    5      c,d
# 6    6    a,d,g
# 7    7      a,b
# 8    8  a,d,e,f
# 9    9  b,d,f,g
# 10  10  b,c,d,f
# 11  11  a,c,d,e
# 12  12  b,e,f,g
# 13  13      c,f
# 14  14      b,d
# 15  15      e,f
# 16  16    b,e,f
# 17  17      a,g
# 18  18  a,c,e,f
# 19  19      a,e
# 20  20      e,f
# 21  21    b,c,g
# 22  22    a,c,f
# 23  23    a,d,f
# 24  24      c,d
# 25  25    c,d,e
# 26  26    a,e,f
# 27  27    a,c,g
# 28  28      e,f
# 29  29  a,c,f,g
# 30  30      b,f
# 31  31      b,f
# 32  32      a,c
# 33  33    b,c,f
# 34  34    a,e,f
# 35  35      a,f
# 36  36      a,c
# 37  37  a,c,e,f
# 38  38      d,e
# 39  39    a,d,f

# %%
import pandas as pd

df = pd.read_table('../files/input/tbl2.tsv')
df = df.sort_values(['c0', 'c5a'])
df
# Out:
#      c0  c5a  c5b
# 1     0  bbb    0
# 2     0  ddd    9
# 3     0  ggg    8
# 4     0  hhh    2
# 0     0  jjj    3
# ..   ..  ...  ...
# 169  38  fff    9
# 170  38  iii    2
# 173  39  ggg    3
# 172  39  hhh    8
# 174  39  jjj    5
#
# [175 rows x 3 columns]

# %%
import pandas as pd

df_tbl2 = pd.read_csv('../files/input/tbl2.tsv', sep='\t')
df_tbl2 = df_tbl2.sort_values(['c0', 'c5a'])
df_aggregated = df_tbl2.groupby('c0').apply(lambda x: ','.join(x['c5a'] + ':' + x['c5b'].astype(str))).reset_index(name='c5')
df_aggregated
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_20768\3342389930.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_aggregated = df_tbl2.groupby('c0').apply(lambda x: ','.join(x['c5a'] + ':' + x['c5b'].astype(str))).reset_index(name='c5')
#     c0                                   c5
# 0    0        bbb:0,ddd:9,ggg:8,hhh:2,jjj:3
# 1    1              aaa:3,ccc:2,ddd:0,hhh:9
# 2    2              ccc:6,ddd:2,ggg:5,jjj:1
# 3    3              bbb:1,eee:7,hhh:9,iii:5
# 4    4              ddd:5,eee:4,iii:6,jjj:3
# 5    5        aaa:7,bbb:2,ccc:4,fff:1,hhh:0
# 6    6  aaa:5,ccc:1,ddd:2,fff:8,iii:0,jjj:7
# 7    7                    ddd:2,fff:3,hhh:1
# 8    8  bbb:0,ccc:5,eee:4,fff:7,ggg:6,iii:9
# ...

# %%
import pandas as pd

# Cargar los archivos tbl0 1.tsv y tbl2.tsv en DataFrames
df_tbl0 = pd.read_csv('../files/input/tbl0.tsv', sep='\t')
df_tbl2 = pd.read_csv('../files/input/tbl2.tsv', sep='\t')

# Asegurarse de que las columnas 'c0' estén presentes en ambos DataFrames
if 'c0' in df_tbl0.columns and 'c0' in df_tbl2.columns:
    # Unir los dos DataFrames en la columna 'c0'
    merged_df = pd.merge(df_tbl0, df_tbl2, on='c0')

    # Agrupar por 'c1' y calcular la suma de 'c5b'
    result_df = merged_df.groupby('c1')['c5b'].sum()

result_df
# Out:
# c1
# A    146
# B    134
# C     81
# D    112
# E    275
# Name: c5b, dtype: int64
